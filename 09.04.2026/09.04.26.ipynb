# %% [markdown]
# Clustering

# %% [markdown]
# Import Libraries

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %% [markdown]
# Load Dataset

# %%
dt = pd.read_csv('global_fuel_prices_2020_2026.csv')
dt.head()
# Out:
#          date        country         region income_level subsidy_level  \
# 0  2020-01-06  United States  North America         High           Low
# 1  2020-01-13  United States  North America         High           Low
# 2  2020-01-20  United States  North America         High           Low
# 3  2020-01-27  United States  North America         High           Low
# 4  2020-02-03  United States  North America         High           Low
#
#    petrol_usd_liter  diesel_usd_liter  lpg_usd_liter  brent_crude_usd  \
# 0             1.465             1.289          1.093            65.75
# 1             1.435             1.319          1.077            65.54
# 2             1.446             1.329          1.080            66.51
# 3             1.488             1.359          1.125            68.79
# 4             1.457             1.341          1.111            68.44
#
#    tax_percentage
# 0            59.6
# 1            27.6
# 2            62.3
# 3            44.8
# 4            51.4

# %% [markdown]
# Select Numeric Columns

# %%
numeric_dt = dt.select_dtypes(include=['int64', 'float64'])
numeric_dt = numeric_dt.dropna()
numeric_dt.head()
# Out:
#    petrol_usd_liter  diesel_usd_liter  lpg_usd_liter  brent_crude_usd  \
# 0             1.465             1.289          1.093            65.75
# 1             1.435             1.319          1.077            65.54
# 2             1.446             1.329          1.080            66.51
# 3             1.488             1.359          1.125            68.79
# 4             1.457             1.341          1.111            68.44
#
#    tax_percentage
# 0            59.6
# 1            27.6
# 2            62.3
# 3            44.8
# 4            51.4

# %% [markdown]
# Scaling

# %%
scaled_num = StandardScaler().fit_transform(numeric_dt)
scaled_num
# Out:
# array([[-0.5302633 , -0.57661598, -0.53523206, -2.15772481,  1.90812432],
#        [-0.54973643, -0.5561386 , -0.54907861, -2.16879373,  0.04798755],
#        [-0.54259628, -0.5493128 , -0.54648239, -2.11766587,  2.06507336],
#        ...,
#        [ 0.51284751,  0.47182611,  0.53874109,  1.22883681,  2.16970605],
#        [ 0.49532169,  0.4656829 ,  0.49373979,  1.22883681,  0.98386886],
#        [ 0.50765467,  0.48616028,  0.50585553,  1.22883681,  2.14645434]],
#       shape=(27468, 5))

# %% [markdown]
# Find Best K

# %%
best_k = 0
best_score = -1

for k in range(2, 10):
    model = KMeans(n_clusters=k, random_state=10)
    labels = model.fit_predict(scaled_num)

    score = silhouette_score(scaled_num, labels)

    if score > best_score:
        best_score = score
        best_k = k

print("Best K:", best_k)
print("Best Score:", best_score)
# Out:
# Best K: 2
# Best Score: 0.4354077623547347

# %% [markdown]
# Final Clustering

# %%
final_model = KMeans(n_clusters=best_k, random_state=10)
final_labels = final_model.fit_predict(scaled_num)

numeric_dt['cluster'] = final_labels

print(numeric_dt.head())
print(numeric_dt['cluster'].value_counts())
# Out:
#    petrol_usd_liter  diesel_usd_liter  lpg_usd_liter  brent_crude_usd  \
# 0             1.465             1.289          1.093            65.75
# 1             1.435             1.319          1.077            65.54
# 2             1.446             1.329          1.080            66.51
# 3             1.488             1.359          1.125            68.79
# 4             1.457             1.341          1.111            68.44
#
#    tax_percentage  cluster
# 0            59.6        1
# 1            27.6        1
# 2            62.3        1
# 3            44.8        1
# 4            51.4        1
# cluster
# 1    15540
# 0    11928
# Name: count, dtype: int64

# %% [markdown]
# Drop Date

# %%
dt2 = dt.drop('date', axis=1)
dt2
# Out:
#              country         region income_level subsidy_level  \
# 0      United States  North America         High           Low
# 1      United States  North America         High           Low
# 2      United States  North America         High           Low
# 3      United States  North America         High           Low
# 4      United States  North America         High           Low
# ...              ...            ...          ...           ...
# 27463         Rwanda         Africa          Low           Low
# 27464         Rwanda         Africa          Low           Low
# 27465         Rwanda         Africa          Low           Low
# 27466         Rwanda         Africa          Low           Low
# 27467         Rwanda         Africa          Low           Low
#
#        petrol_usd_liter  diesel_usd_liter  lpg_usd_liter  brent_crude_usd  \
# 0                 1.465             1.289          1.093            65.75
# 1                 1.435             1.319          1.077            65.54
# 2                 1.446             1.329          1.080            66.51
# 3                 1.488             1.359          1.125            68.79
# 4                 1.457             1.341          1.111            68.44
# ...                 ...               ...            ...              ...
# 27463             3.036             2.849          2.294           130.00
# 27464             3.020             2.861          2.248           130.00
# 27465             3.072             2.825          2.334           130.00
# 27466             3.045             2.816          2.282           130.00
# 27467             3.064             2.846          2.296           130.00
#
#        tax_percentage
# 0                59.6
# 1                27.6
# 2                62.3
# 3                44.8
# 4                51.4
# ...               ...
# 27463            62.3
# 27464            43.3
# 27465            64.1
# 27466            43.7
# 27467            63.7
#
# [27468 rows x 9 columns]

# %% [markdown]
# One-Hot Encoding

# %%
dt2 = pd.get_dummies(dt2)
dt2 = dt2.dropna()

dt2.head()
# Out:
#    petrol_usd_liter  diesel_usd_liter  lpg_usd_liter  brent_crude_usd  \
# 0             1.465             1.289          1.093            65.75
# 1             1.435             1.319          1.077            65.54
# 2             1.446             1.329          1.080            66.51
# 3             1.488             1.359          1.125            68.79
# 4             1.457             1.341          1.111            68.44
#
#    tax_percentage  country_Algeria  country_Angola  country_Argentina  \
# 0            59.6            False           False              False
# 1            27.6            False           False              False
# 2            62.3            False           False              False
# 3            44.8            False           False              False
# 4            51.4            False           False              False
#
#    country_Australia  country_Austria  ...  region_North America  \
# 0              False            False  ...                  True
# 1              False            False  ...                  True
# 2              False            False  ...                  True
# 3              False            False  ...                  True
# 4              False            False  ...                  True
#
#    region_Oceania  region_South America  income_level_High  income_level_Low  \
# 0           False                 False               True             False
# 1           False                 False               True             False
# 2           False                 False               True             False
# 3           False                 False               True             False
# 4           False                 False               True             False
#
#    income_level_Middle  subsidy_level_High  subsidy_level_Low  \
# 0                False               False               True
# 1                False               False               True
# 2                False               False               True
# 3                False               False               True
# 4                False               False               True
#
#    subsidy_level_Medium  subsidy_level_Very High
# 0                 False                    False
# 1                 False                    False
# 2                 False                    False
# 3                 False                    False
# 4                 False                    False
#
# [5 rows x 103 columns]

# %% [markdown]
# Scaling

# %%
scaled_all = StandardScaler().fit_transform(dt2)
scaled_all
# Out:
# array([[-0.5302633 , -0.57661598, -0.53523206, ...,  0.95346259,
#         -0.52223297, -0.36760731],
#        [-0.54973643, -0.5561386 , -0.54907861, ...,  0.95346259,
#         -0.52223297, -0.36760731],
#        [-0.54259628, -0.5493128 , -0.54648239, ...,  0.95346259,
#         -0.52223297, -0.36760731],
#        ...,
#        [ 0.51284751,  0.47182611,  0.53874109, ...,  0.95346259,
#         -0.52223297, -0.36760731],
#        [ 0.49532169,  0.4656829 ,  0.49373979, ...,  0.95346259,
#         -0.52223297, -0.36760731],
#        [ 0.50765467,  0.48616028,  0.50585553, ...,  0.95346259,
#         -0.52223297, -0.36760731]], shape=(27468, 103))

# %% [markdown]
# Find Best K

# %%
best_k2 = 0
best_score2 = -1

for k in range(2, 10):
    model = KMeans(n_clusters=k, random_state=10)
    labels = model.fit_predict(scaled_all)

    score = silhouette_score(scaled_all, labels)

    if score > best_score2:
        best_score2 = score
        best_k2 = k

print("Best K:", best_k2)
print("Best Score:", best_score2)
# Out:
# Best K: 9
# Best Score: 0.11256908592955879

# %% [markdown]
# Final Clustering

# %%
final_model2 = KMeans(n_clusters=best_k2, random_state=10)
final_labels2 = final_model2.fit_predict(scaled_all)

dt2['cluster'] = final_labels2

print(dt2.head())
print(dt2['cluster'].value_counts())
# Out:
#    petrol_usd_liter  diesel_usd_liter  lpg_usd_liter  brent_crude_usd  \
# 0             1.465             1.289          1.093            65.75
# 1             1.435             1.319          1.077            65.54
# 2             1.446             1.329          1.080            66.51
# 3             1.488             1.359          1.125            68.79
# 4             1.457             1.341          1.111            68.44
#
#    tax_percentage  country_Algeria  country_Angola  country_Argentina  \
# 0            59.6            False           False              False
# 1            27.6            False           False              False
# 2            62.3            False           False              False
# 3            44.8            False           False              False
# 4            51.4            False           False              False
#
#    country_Australia  country_Austria  ...  region_Oceania  \
# 0              False            False  ...           False
# 1              False            False  ...           False
# 2              False            False  ...           False
# 3              False            False  ...           False
# 4              False            False  ...           False
#
#    region_South America  income_level_High  income_level_Low  \
# 0                 False               True             False
# 1                 False               True             False
# 2                 False               True             False
# 3                 False               True             False
# 4                 False               True             False
#
#    income_level_Middle  subsidy_level_High  subsidy_level_Low  \
# 0                False               False               True
# 1                False               False               True
# 2                False               False               True
# 3                False               False               True
# 4                False               False               True
#
#    subsidy_level_Medium  subsidy_level_Very High  cluster
# 0                 False                    False        2
# 1                 False                    False        2
# 2                 False                    False        2
# 3                 False                    False        2
# 4                 False                    False        2
#
# [5 rows x 104 columns]
# cluster
# 2    8175
# 4    3924
# 1    3597
# 0    3597
# 5    2616
# 3    2289
# 6    1635
# 8     981
# 7     654
# Name: count, dtype: int64

# %% [markdown]
# DBSCAN

# %% [markdown]
# Import

# %%
from sklearn.cluster import DBSCAN
from sklearn.neighbors import NearestNeighbors
import numpy as np

# %% [markdown]
# Find Auto eps

# %%
# find nearest neighbors
neighbors = NearestNeighbors(n_neighbors=5)
neighbors_fit = neighbors.fit(scaled_num)

distances, indices = neighbors_fit.kneighbors(scaled_num)

# sort distances
distances = np.sort(distances[:, 4])

# auto eps (using percentile)
eps = np.percentile(distances, 90)

print("Auto eps:", eps)
# Out:
# Auto eps: 0.17023439185005262

# %% [markdown]
# Apply DBSCAN

# %%
dbscan = DBSCAN(eps=eps, min_samples=5)

db_labels = dbscan.fit_predict(scaled_num)

# %% [markdown]
# Add Result

# %%
numeric_dt['db_cluster'] = db_labels

print(numeric_dt.head())
print(numeric_dt['db_cluster'].value_counts())
# Out:
#    petrol_usd_liter  diesel_usd_liter  lpg_usd_liter  brent_crude_usd  \
# 0             1.465             1.289          1.093            65.75
# 1             1.435             1.319          1.077            65.54
# 2             1.446             1.329          1.080            66.51
# 3             1.488             1.359          1.125            68.79
# 4             1.457             1.341          1.111            68.44
#
#    tax_percentage  cluster  db_cluster
# 0            59.6        1           0
# 1            27.6        1           0
# 2            62.3        1           0
# 3            44.8        1           0
# 4            51.4        1           0
# db_cluster
#  2     16509
#  0      8419
# -1      1337
#  20      219
#  19      134
#        ...
#  42        4
#  46        4
#  82        4
#  45        3
#  65        2
# Name: count, Length: 88, dtype: int64
